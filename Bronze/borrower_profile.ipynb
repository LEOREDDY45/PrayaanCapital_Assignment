# %%
# %run ./config

# %%
df_schema=StructType([StructField('borrower_id', StringType(), True),
                     StructField('urs_score', IntegerType(), True),
                     StructField('badge', StringType(), True),
                     StructField('onboarding_date', DateType(), True)])

# %%
df=spark.read.schema(df_schema).csv(bronze+'/borrower_profile.csv', header=True)

# %%
df=df.filter((col('onboarding_date')<=current_date()) & 
             (col("borrower_id").isNotNull()) & 
             (col("urs_score")>0))

# %%
df.write.mode('overwrite').csv(silver+'/borrower_profile.csv', header=True)

# %%
df=spark.read.csv(silver+'/borrower_profile.csv', header=True, inferSchema=True)
df.display()
