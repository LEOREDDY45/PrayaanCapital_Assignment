# %%
# %run ./config

# %%
df_schema=StructType([
    StructField('event_id',StringType(),True),
    StructField('loan_id',StringType(),True),
    StructField('event_date',DateType(),True),
    StructField('status',StringType(),True)
])

# %%
df=spark.read.schema(df_schema).option('header',True).csv(bronze+'/loan_status_events.csv')

# %%
df=df.filter((col("event_date").isNotNull()) & (col("event_date")< current_date()))

# %%
df.write.mode('overwrite').csv(silver+'/loan_status_events.csv', header=True)

# %%
df=spark.read.csv(silver+'/loan_status_events.csv', header=True, inferSchema=True)
df.display()
